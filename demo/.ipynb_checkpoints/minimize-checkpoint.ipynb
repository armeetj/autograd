# %%
import sys, os
sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'src'))
# import autograd library
import grad
import numpy as np
import matplotlib.pyplot as plt

# %%
# initialize params
x = grad.Value(7)
y = grad.Value(3)

# %%
verbose = True
lr = 0.001
epochs = 20000
xs = np.arange(0, epochs + 1, 1)
ys = []

for i in range(epochs + 1):
    # forward
    f = (x - y) ** 3 + y.exp()
    f = f.relu() + y
    ys.append(f.data)

    # backward
    f.backward()
    
    # update params
    x.data -= lr * x.grad
    y.data -= lr * y.grad

    # zero grad for next iteration
    x.zero_grad()
    y.zero_grad()

    # debugging info
    if verbose and i % (epochs / 10) == 0:        
        print(f"[{i}]\tx, y: {x.data} {y.data}: f(x): {f.data}")

# plot f(x, y) over time (iterations)
plt.plot(xs, ys)
plt.xlabel("# iterations")
plt.ylabel("f(x, y)")
plt.show()
# Out:
# [0]	x, y: 3.8986383900561035 2.3394897432809256: f(x): 16.57589835402631
# [2000]	x, y: 0.03067364719237007 -0.5001359004611692: f(x): 0.2571670214150128
# [4000]	x, y: -1.3433356893986639 -1.7882191988405738: f(x): -1.5322279674610955
# [6000]	x, y: -2.4564567266523856 -2.8773342331089697: f(x): -2.7459383677216813
# [8000]	x, y: -3.495539777665102 -3.908329855358803: f(x): -3.8173979369728563
# [10000]	x, y: -4.50960366749995 -4.919509151252631: f(x): -4.842825757810596
# [12000]	x, y: -5.514736287076211 -5.923592401885769: f(x): -5.852068403891592
# [14000]	x, y: -6.516618959165173 -6.9250906101013925: f(x): -6.8554536892738716
# [16000]	x, y: -7.517310812456819 -7.925641239461822: f(x): -7.856697061565789
# [18000]	x, y: -8.517565230647806 -8.9258437329682: f(x): -8.857154201925319
# [20000]	x, y: -9.517658812288058 -9.925918216465524: f(x): -9.857322337851318

# %%
# %matplotlib notebook
# %matplotlib inline

import matplotlib.animation as animation

sampled_xs = xs[::200]
sampled_ys = ys[::200]

def update(frame):
    plt.cla()  # Clear the previous frame
    plt.plot(sampled_xs[:frame], sampled_ys[:frame])  # Plot ys against xs up to the current frame
    plt.xlim(0, 20000)
    plt.ylim(-10, 20)
    plt.xlabel('# iterations')
    plt.ylabel('f(x, y)')
    plt.title('Minimizing f over 20k iterations')
    plt.grid(True)
    
fig = plt.figure()
ani = animation.FuncAnimation(fig, update, frames=len(sampled_xs), interval=1)  # Interval in milliseconds between frames
writer = animation.FFMpegWriter(fps=30, bitrate=1800)
ani.save('minimize.mp4', writer=writer)
# Out:
# MovieWriter stderr:
# [rawvideo @ 0x139e04a10] Invalid buffer size, packet size 655360 < expected frame_size 1228800
# Error while decoding stream #0:0: Invalid argument
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/animation.py:231, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     230 try:
# --> 231     yield self
#     232 finally:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/animation.py:1099, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1098         frame_number += 1
# -> 1099 writer.grab_frame(**savefig_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/animation.py:357, in MovieWriter.grab_frame(self, **savefig_kwargs)
#     356 # Save the figure data to the sink, using the frame format and dpi.
# --> 357 self.fig.savefig(self._proc.stdin, format=self.frame_format,
#     358                  dpi=self.dpi, **savefig_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:448, in FigureCanvasAgg.print_raw(self, filename_or_obj)
#     447 with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 448     fh.write(renderer.buffer_rgba())
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# Cell In[17], line 22
#      20 ani = animation.FuncAnimation(fig, update, frames=len(sampled_xs), interval=1)  # Interval in milliseconds between frames
#      21 writer = animation.FFMpegWriter(fps=30, bitrate=1800)
# ---> 22 ani.save('minimize.mp4', writer=writer)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/animation.py:1077, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1073 savefig_kwargs['transparent'] = False   # just to be safe!
#    1074 # canvas._is_saving = True makes the draw_event animation-starting
#    1075 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1076 # widget (both are likewise done in savefig()).
# -> 1077 with mpl.rc_context({'savefig.bbox': None}), \
#    1078      writer.saving(self._fig, filename, dpi), \
#    1079      cbook._setattr_cm(self._fig.canvas,
#    1080                        _is_saving=True, manager=None):
#    1081     for anim in all_anim:
#    1082         anim._init_draw()  # Clear the initial frame
#
# File ~/anaconda3/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/animation.py:233, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     231     yield self
#     232 finally:
# --> 233     self.finish()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/animation.py:347, in MovieWriter.finish(self)
#     343     _log.log(
#     344         logging.WARNING if self._proc.returncode else logging.DEBUG,
#     345         "MovieWriter stderr:\n%s", err)
#     346 if self._proc.returncode:
# --> 347     raise subprocess.CalledProcessError(
#     348         self._proc.returncode, self._proc.args, out, err)
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '640x480', '-pix_fmt', 'rgba', '-r', '30', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-b', '1800k', '-y', 'minimize.mp4']' returned non-zero exit status 255.
